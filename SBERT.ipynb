# %%
import numpy as np
import pandas as pd
from numpy import dot
from numpy.linalg import norm
import urllib.request
from sentence_transformers import SentenceTransformer
import torch

train_data  = pd.read_csv('/content/drive/MyDrive/자진프/Vat_QnA.csv')
train_data.head()

model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')

from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

embeddings = []
for index, row in tqdm(train_data.iterrows(), total=len(train_data), desc="Encoding"):
    question = row['question']
    embedding = torch.tensor(model.encode([question])[0]).to(device)
    embeddings.append(embedding)

def return_answer(question):
    embedding = model.encode(question)
    train_data['score'] = train_data.apply(lambda x: cos_sim(x['embedding'], embedding), axis=1)
    return train_data.loc[train_data['score'].idxmax()]['answer']

return_answer('포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요')


### 모델 개선 예시 y = aX1+bX2+c
# Out:
# Encoding: 100%|██████████| 22955/22955 [05:59<00:00, 63.83it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7cdbbb46e7a3> in <cell line: 29>()
#      27     return train_data.loc[train_data['score'].idxmax()]['answer']
#      28
# ---> 29 return_answer('포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요')
#      30
#      31
#
# <ipython-input-7-7cdbbb46e7a3> in return_answer(question)
#      24 def return_answer(question):
#      25     embedding = model.encode(question)
# ---> 26     train_data['score'] = train_data.apply(lambda x: cos_sim(x['embedding'], embedding), axis=1)
#      27     return train_data.loc[train_data['score'].idxmax()]['answer']
#      28
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# ...

# %%
def return_answer(question):
    embedding = model.encode(question)
    train_data['score'] = train_data.apply(lambda x: cos_sim(x['embedding'], embedding), axis=1)
    return train_data.loc[train_data['score'].idxmax()]['answer']

return_answer('포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'embedding'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 66.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.4 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=fccb76e5ccfc91cd445e3e8ea21dc92e290f21fec1fcebc4db3d710f38c27358
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %%
question = row['question']
embedding = torch.tensor(model.encode([question])[0]).to(device)
