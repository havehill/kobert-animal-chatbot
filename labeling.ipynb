# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv("/content/drive/MyDrive/자진프/Vat_QnA.csv")

# %%
sample_5000 = raw.sample(5000, random_state=1004)
sample_2500 = sample_5000[2500:]

# %% [markdown]
# # call chat gpt api

# %%
# !pip install openai

# %%
import os
import openai

openai.api_key = "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"
# Out:
# 고양이/이물질 삼킴
# 강아지/호흡기 질환/재채기

# %%
# test

messages = [
    {"role": "system", "content": "너는 반려동물 질병 카테고리를 라벨링해야 해.\
                                    [예시]\
                                    강아지/안구질환/결막염\
                                    고양이/내장질환/토\
                                    새/피부질환/거스름"},
    {"role": "user", "content": "라벨링해줘. 고양이 실 삼킴 고양이가 얇은 실 25센치 정도를 삼켰어요 입 안에 확인해보니까 이빨에 걸려있지도 않아서 아예 삼킨거 같아요 어떡하죠 응아로 나온다고는 하는데 실 길이가 긴거 같아서 ㅠㅠㅠ 고양이 나이는 5-6살 정도예요"},
]

completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages
)

# %%
print(completion.choices[0].message.content)
# Out:
# 고양이/소화기 질환/이물질 섭취

# %% [markdown]
# # gpt labeling

# %%
def labeling_gpt(data):
    messages = [
    {"role": "system", "content": "너는 주어진 질문마다 반려동물 질병 카테고리를 라벨링해야 해. 라벨은 한 질문당 하나며, 형식은 주어진 [예시]에 따라야 해. 내가 준 분류에 한정되게 라벨링 해야 해."},
    {"role": "user", "content": "대분류 : 강아지, 고양이, 새, 토끼, 반려동물 \
                                중분류 : 소화기질환, 생식기질환, 호흡기질환, 피부질환, 안구질환, 구강질환, 심장질환, 슬개골탈구, 종양, 중독, 이물질섭취, 행동\
                                주어진 대분류/중분류만으로 '강아지/안구질환'처럼 다음 질문을 라벨링해줘."+data},
    {"role": "assistant", "content" : "내가 준 분류에 한정되게 라벨링해야 되고, 주어진 분류들에 해당되는 게 없을 때는 '알수없음'이라고 라벨링 해"}
    ]

    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages
    )

    print(completion.choices[0].message.content)
    labels.append(completion.choices[0].message.content)

# %%
#labels=[]
test_10 = list(sample_2500.question.values[2429:2500])

for i in test_10:
    labeling_gpt(i)
# Out:
# 종양
# 강아지/행동
# 강아지/호흡기질환
# 고양이/안구질환
# 강아지/안구질환
# 강아지/신경계질환
# 강아지/피부질환
# 강아지/알수없음
# 강아지/피부질환
# 고양이/구강질환
# 고양이/소화기질환
# 고양이/소화기질환
# 강아지/피부질환
# 강아지/소화기질환
# 강아지/소화기질환
# 강아지/영양 및 관리상의 질환
# 강아지/소화기질환
# 강아지/알수없음
# 강아지/생식기질환
# 강아지/종양
# 강아지/이물질섭취
# 강아지/알수없음
# 강아지/슬개골탈구
# 강아지/피부질환
# 강아지/신경질환
# 강아지/신장질환
# 고양이/신장질환
# 고양이/알수없음
# 강아지/소화기질환
# 강아지/슬개골탈구
# 강아지/생식기질환
# 강아지/생식기질환
# 고양이/소화기질환
# 강아지/생식기질환, 강아지/안구질환
# 강아지/피부질환
# 강아지/생식기질환
# 강아지/이물질섭취
# 강아지/생식기질환
# 강아지/호흡기질환
# 강아지/생식기질환
# 강아지/소화기질환, 강아지/알수없음
# 강아지/시각장애
# 강아지/알수없음
# 강아지/이물질섭취
# 강아지/피부질환
# 강아지/피부질환
# 강아지/알수없음
# 강아지/소화기질환
# 강아지/피부질환
# 강아지/이물질섭취
# 강아지/소화기질환
# 강아지/피부질환
# 강아지/소화기질환
# 강아지/피부질환
# 강아지/소화기질환
# 고양이/안구질환
# 강아지/안구질환
# 강아지/안구질환
# 강아지/안구질환
# 고양이/소화기질환
# 강아지/피부질환
# 고양이/알수없음
# 고양이/호흡기질환
# 강아지/생식기질환
# 강아지/호흡기질환
# 강아지/행동
# 반려동물/행동
# 강아지/슬개골탈구
# 강아지/소화기질환
# 강아지/슬개골탈구
# 강아지/중독

# %%
len(labels)
# Out:
# 2500

# %%
#sample_2500['label'] = np.NaN
# Out:
# <ipython-input-164-b7ed976be739>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_2500['label'] = np.NaN

# %%
sample_2500.iloc[2000:2500,3] = labels[2000:2500]

# %%
sample_2500
# Out:
#                                                 question  \
# 10484  고양이 실 삼킴 고양이가 얇은 실 25센치 정도를 삼켰어요 입 안에 확인해보니까 이...
# 4203   강아지 연속 재채기 전문가 답변 부탁드려요..  심장병 있는 아이인데요, 기침과 재...
# 18617  저희 집 개가 호흡기관이 안 좋은 건가요 ㅠㅠ?? 동영상처럼 저희 집 강아지가 이상...
# 11309  [나눈질문2] 현재 16세 암컷 강아지구요.. 중성 현재 16세 암컷 강아지구요.....
# 9422   너무 급합니다.ㅠㅠ 새벽까지만해도 건강하던 아이가 아침이 되고 나서 주변에 피와 배...
# 5420   강아지 뇌진탕 질문 강아지가 갑자기 누워서 일어나지도 못하고 눈도 잘 못뜨고 그래서...
# 927             강아지 앞발 뒤에 혹같은 게 양발 모두에 있어요. 문제가 있는 걸까요?
# 1751   강아지 오줌에서 피가 나왔어요 7년된 중성화시킨 수컷 말티즈 (7kg)인데 잠깐 나...
# 15568  제가 먹다가 뱉어논 청포도껍질?한알을 푸들8개월정도된 강아지가 먹었는데 괜찮을까요?...
# 20759  개가 심장사상충에 걸려 식욕이 없습니다. 밥을 어떻게 먹이죠? 진돗개 8살이구요 며...
# 21730  고양이가 많이 안좋아요 얼마전 박스덤이에서 고양이 한마리를 주워왔습니다 태어난지 약...
# 7651   오늘 산책을 갔다와서 다리에 이상이 생겼습니다 대형견이고, 오늘 낮에 산책을 갔다와...
# 5616   강아지 예방접종 후 밥을 안먹어요 강아지가 예방접종 후에 밥을 잘 만먹어요 ㅠㅠ 어...
# 21346  중성화수술 이후 넥칼라 찼던 것 처럼 귀가 모였습니다. ㅠㅠㅠ닥스훈트 중성화 시키고...
# 1781   안녕하세요 작년 3월에 처음발견했어요 오른쪽뒷다리 뼈있는쪽에 아주작게 하얗게 ᆢ 핧...
# ...

# %%
sample_2500.to_csv("/content/drive/MyDrive/자진프/sample_2500_labeled_new.csv")

# %% [markdown]
# # 전처리 (3개의 csv 파일 만들기)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/자진프/data/labeled_dataset.csv")
df = df.drop(columns = ['Unnamed: 0'])

# %%
df
# Out:
#         idx                                           question  \
# 0     10484  고양이 실 삼킴 고양이가 얇은 실 25센치 정도를 삼켰어요 입 안에 확인해보니까 이...
# 1      4203  강아지 연속 재채기 전문가 답변 부탁드려요..  심장병 있는 아이인데요, 기침과 재...
# 2     18617  저희 집 개가 호흡기관이 안 좋은 건가요 ㅠㅠ?? 동영상처럼 저희 집 강아지가 이상...
# 3     11309  [나눈질문2] 현재 16세 암컷 강아지구요.. 중성 현재 16세 암컷 강아지구요.....
# 4      9422  너무 급합니다.ㅠㅠ 새벽까지만해도 건강하던 아이가 아침이 되고 나서 주변에 피와 배...
# ...     ...                                                ...
# 5461   7807  강아지 유골 4년 조금 안되게 키운 강아지가 있었는데.. 척수연화증?이라는 병에 걸...
# 5462  13912  강아지 턱에 뭐가 잡혀요 귀밑 턱쪽에 양쪽으로 혹이라해야하나 뭐가 잡히더라고요  인...
# 5463  14395  소형견 호흡이상? 들숨여러번 주둥이 짧은 말티즈애긴데용 원래 들숨날숨 이렇게 숨을 ...
# 5464   1895  저희강아지가 포도를 먹었어요 2kg의 작은 말티즈인데 괜찮을까요? 포도 크기는 조금...
# 5465  12282   강아지 털을 빗기다보니 피부에 흉터?처럼 흰색으로 나있는데 뭘까요..? 아파하진않...
#
#                                                  answer  \
# 0     고양이는 호기심으로 이물질을 먹고 문제가 되는 경우가 많습니다. 선상이물(실/끈)과...
# 1     영상만으로는 정확한 감별진단이 어려울 수 있습니다. 재채기의 원인은 여러가지가 있을...
# ...

# %%
drop_list = [4, 83, 88, 140, 145, 208, 336, 446, 459, 468, 508, 581, 659, 673, 676, 702, 791, 837, 1189, 1210, 1248, 1276, 1314, 1329, 1338, 1408, 1439, 1472, 1510, 1534, 1753, 1755, 1826, 1904, 1942, 2073, 2293, 2296, 2388, 2414, 2473, 2510, 2689, 2692, 2873, 3031, 3078, 3167, 3170, 3208, 3264, 3455, 3524, 3813, 4057, 4170, 4179, 4214, 4216, 4394, 4425, 4500, 4543, 4633, 4707, 4982, 5090, 5158, 5218, 5324, 5384, 5436]

# %%
a = df.label.value_counts()
for i,j in zip(a.keys(), a.values):
    print(i, j)
# Out:
# 강아지/소화기질환 819
# 강아지/안구질환 612
# 강아지/피부질환 545
# 강아지/생식기질환 404
# 강아지/슬개골탈구 320
# 강아지/알수없음 283
# 강아지/이물질섭취 277
# 강아지/호흡기질환 207
# 강아지/중독 202
# 강아지/구강질환 182
# 고양이/소화기질환 174
# 강아지/행동 133
# 강아지/신경계질환 129
# 강아지/종양 124
# 강아지/심장질환 119
# 고양이/생식기질환 111
# 고양이/피부질환 107
# 고양이/알수없음 101
# 고양이/안구질환 91
# 강아지/예방접종 50
# 고양이/이물질섭취 38
# 강아지/신장질환 34
# 고양이/구강질환 32
# 강아지/골절 32
# 강아지/혈액질환 30
# 고양이/호흡기질환 24
# 고양이/행동 23
# 고양이/슬개골탈구 20
# 강아지/감염성질환 19
# 강아지/귀질환 18
# 반려동물/알수없음 17
# 새/알수없음 15
# 강아지/식이질환 14
# 고양이/예방접종 14
# 강아지/중성화수술 12
# 고양이/중독 12
# 고양이/종양 10
# 강아지/통증 9
# 고양이/심장질환 8
# 새/안구질환 8
# 고양이/중성화수술 7
# 고양이/신장질환 7
# 강아지/근육질환 6
# 고양이/골절 5
# 반려동물/안구질환 5
# 고양이/귀질환 5
# 새/피부질환 5
# 고양이/혈액질환 4
# 새/호흡기질환 4
# 고양이/감염성질환 4
# 고양이/식이질환 4
# 고양이/신경계질환 4
# 새/소화기질환 3
# 고양이/통증 3
# 새/생식기질환 2
# 반려동물/이물질섭취 2
# 강아지/알러지질환 2
# 새/이물질섭취 1
# 새/식이질환 1
# 반려동물/신경계질환 1
# 새/귀질환 1
# 반려동물/귀질환 1
# 토끼/피부질환 1
# 고양이/근육질환 1
# 반려동물/피부질환 1
# 토끼/알수없음 1
# 새/중독 1
# 토끼/안구질환 1
# 새/신경계질환 1
# 반려동물/행동 1
# 반려동물/소화기질환 1
# 고양이/알러지질환 1

# %% [markdown]
# ## dialog_category.txt
# 클래스 \t 레이블 (레이블인코딩)

# %%
import random
random.seed('1004')
labels = list(df.label.value_counts().keys())
random.shuffle(labels)

# %%
with open('/content/drive/MyDrive/자진프/data/labeling/dialog_category.txt','w') as f:
    for i, label in enumerate(labels):
        txt = f"{label}\t{i}"
        f.write(txt + "\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-a3dc5ab643c9> in <cell line: 1>()
# ----> 1 with open('/content/drive/MyDrive/자진프/data/labeling/dialog_category.txt','w') as f:
#       2     for i, label in enumerate(labels):
#       3         txt = f"{label}\t{i}"
#       4         f.write(txt + "\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/자진프/data/labeling/dialog_category.txt'

# %% [markdown]
# ## dialog_for_text_classification.txt
# 질문 \t 레이블

# %%
# df에 encoding label 붙이기

numbers = np.arange(0, len(labels)).tolist()
labels_for_class = dict(zip(labels, numbers))

# %%
df['encoding'] = 0
for i in range(len(df)):
    df.iloc[i,5] = int(labels_for_class[df.label[i]])

# %%
df.head()
# Out:
#      idx                                           question  \
# 0  10484  고양이 실 삼킴 고양이가 얇은 실 25센치 정도를 삼켰어요 입 안에 확인해보니까 이...
# 1   4203  강아지 연속 재채기 전문가 답변 부탁드려요..  심장병 있는 아이인데요, 기침과 재...
# 2  18617  저희 집 개가 호흡기관이 안 좋은 건가요 ㅠㅠ?? 동영상처럼 저희 집 강아지가 이상...
# 3  11309  [나눈질문2] 현재 16세 암컷 강아지구요.. 중성 현재 16세 암컷 강아지구요.....
# 4   9422  너무 급합니다.ㅠㅠ 새벽까지만해도 건강하던 아이가 아침이 되고 나서 주변에 피와 배...
#
#                                               answer  \
# 0  고양이는 호기심으로 이물질을 먹고 문제가 되는 경우가 많습니다. 선상이물(실/끈)과...
# 1  영상만으로는 정확한 감별진단이 어려울 수 있습니다. 재채기의 원인은 여러가지가 있을...
# 2  강아지의 이상증상에 걱정이 많으시죠? 올려주신 동영상 만으로 어떤 질병인지 정확한게...
# 3  중성화 수술과 유선종양 수술을 왜 안했는지...... 이제와서 후회한 들 무슨 의미...
# 4  자궁탈 / 직장탈이 의심됩니다. 사진이 명확하지 않아서 정확한 구조가 분간되지 않네...
#
#                                                  url      label  encoding
# 0  https://kin.naver.com/qna/detail.naver?d1id=8&...  고양이/이물질섭취        67
# 1  https://kin.naver.com/qna/detail.naver?d1id=8&...  강아지/호흡기질환        38
# ...

# %%
# 512 token 넘는거 제거

drop_list = [3, 82, 87, 139, 144, 207, 335, 445, 458, 467, 507, 580, 658, 672, 675, 701, 790, 836, 1188, 1209, 1247, 1275, 1313, 1328, 1337, 1407, 1438, 1471, 1509, 1533, 1752, 1754, 1825, 1903, 1941, 2072, 2292, 2295, 2387, 2413, 2472, 2509, 2688, 2691, 2872, 3030, 3077, 3166, 3169, 3207, 3263, 3454, 3523, 3812, 4056, 4169, 4178, 4213, 4215, 4393, 4424, 4499, 4542, 4632, 4706, 4981, 5089, 5157, 5217, 5323, 5383, 5435]
drp_df = df.drop(drop_list, axis=0)

# %%
with open('/content/drive/MyDrive/자진프/kobert-wellness-chatbot/data/dialog_text_for_classification.txt','w') as f:
    for i in range(len(drp_df)):
        txt = f"{drp_df.iloc[i,1]}\t{drp_df.iloc[i,5]}"
        f.write(txt + "\n")

# %%
pd.read_csv("dr"/content/drive/MyDrive/자진프/data/data_for_train")")

# %%
drp_df
# Out:
#         idx                                           question  \
# 0     10484  고양이 실 삼킴 고양이가 얇은 실 25센치 정도를 삼켰어요 입 안에 확인해보니까 이...
# 1      4203  강아지 연속 재채기 전문가 답변 부탁드려요..  심장병 있는 아이인데요, 기침과 재...
# 2     18617  저희 집 개가 호흡기관이 안 좋은 건가요 ㅠㅠ?? 동영상처럼 저희 집 강아지가 이상...
# 4      9422  너무 급합니다.ㅠㅠ 새벽까지만해도 건강하던 아이가 아침이 되고 나서 주변에 피와 배...
# 5      5420  강아지 뇌진탕 질문 강아지가 갑자기 누워서 일어나지도 못하고 눈도 잘 못뜨고 그래서...
# ...     ...                                                ...
# 5461   7807  강아지 유골 4년 조금 안되게 키운 강아지가 있었는데.. 척수연화증?이라는 병에 걸...
# 5462  13912  강아지 턱에 뭐가 잡혀요 귀밑 턱쪽에 양쪽으로 혹이라해야하나 뭐가 잡히더라고요  인...
# 5463  14395  소형견 호흡이상? 들숨여러번 주둥이 짧은 말티즈애긴데용 원래 들숨날숨 이렇게 숨을 ...
# 5464   1895  저희강아지가 포도를 먹었어요 2kg의 작은 말티즈인데 괜찮을까요? 포도 크기는 조금...
# 5465  12282   강아지 털을 빗기다보니 피부에 흉터?처럼 흰색으로 나있는데 뭘까요..? 아파하진않...
#
#                                                  answer  \
# 0     고양이는 호기심으로 이물질을 먹고 문제가 되는 경우가 많습니다. 선상이물(실/끈)과...
# 1     영상만으로는 정확한 감별진단이 어려울 수 있습니다. 재채기의 원인은 여러가지가 있을...
# ...

# %% [markdown]
# ## dialog_answer.txt
# 클래스 \t 답변

# %%
with open('/content/drive/MyDrive/자진프/kobert-wellness-chatbot/data/dialog_answer.txt','w') as f:
    for i in range(len(drp_df)):
        txt = f"{drp_df.iloc[i,4]}\t{drp_df.iloc[i,2]}"
        f.write(txt + "\n")
